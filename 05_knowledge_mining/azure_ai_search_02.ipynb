# %%
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents import SearchClient
from azure.search.documents.models import VectorizedQuery, VectorizableTextQuery
from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from azure.core.credentials import AzureKeyCredential
from azure.search.documents.indexes.models import (
    BinaryQuantizationCompression,
    HnswAlgorithmConfiguration,
    HnswParameters,
    ScalarQuantizationCompression,
    ScalarQuantizationParameters,
    SearchField,
    SearchFieldDataType,
    SearchIndex,
    SimpleField,
    VectorSearch,
    VectorSearchAlgorithmKind,
    VectorSearchProfile,
    VectorSearchCompressionRescoreStorageMethod,
    RescoringOptions
    )
from azure.core.exceptions import ResourceExistsError
from dotenv import load_dotenv
import requests
from openai import AzureOpenAI
import os
import json
from tabulate import tabulate
from datasets import load_dataset
import pyarrow.parquet as pq
import pyarrow as pa
import base64
import time
from datetime import datetime
from typing import List, Dict, Any
import azure.identity

# %%
load_dotenv(override=True)
# Out:
# True

# %%
AZURE_AI_SEARCH_ENDPOINT = os.getenv("AZURE_SEARCH_SERVICE_ENDPOINT")
AZURE_AI_SEARCH_API_KEY = os.getenv("AZURE_SEARCH_API_KEY")
AZURE_AI_SEARCH_INDEX_NAME = os.getenv("AZURE_SEARCH_INDEX_NAME")
AZURE_AI_SEARCH_BASIC_ENDPOINT = os.getenv("AZURE_SEARCH_BASIC_ENDPOINT")
AZURE_AI_SEARCH_BASIC_API_KEY = os.getenv("AZURE_SEARCH_BASIC_API_KEY")
AZURE_AI_SEARCH_BASIC_INDEX_NAME = os.getenv("AZURE_SEARCH_BASIC_INDEX_NAME")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_CHAT_COMPLETION_DEPLOYED_MODEL_NAME = os.getenv("AZURE_OPENAI_CHAT_COMPLETION_DEPLOYED_MODEL_NAME")
AZURE_OPENAI_EMBEDDING_DEPLOYED_MODEL_NAME = os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYED_MODEL_NAME")

# %%
index_client = SearchIndexClient(
    endpoint = AZURE_AI_SEARCH_ENDPOINT,
    credential = AzureKeyCredential(AZURE_AI_SEARCH_API_KEY)
)

# %% [markdown]
# ### **INDEX CREATION**

# %%
index = SearchIndex(
    name="tinyindex",
    fields=[
        SimpleField(name="id", type=SearchFieldDataType.String, key=True),
        SearchField(
            name="embedding",
            type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
            searchable=True,
            vector_search_dimensions=3072,
            vector_search_profile_name="embedding_profile",
            stored=False
        ),
    ],
    vector_search=VectorSearch(
        algorithms=[
            HnswAlgorithmConfiguration(
                name="hnsw_config",
                kind=VectorSearchAlgorithmKind.HNSW,
                parameters=HnswParameters(metric="cosine"),
            )
        ],
        compressions=[
            BinaryQuantizationCompression(
                compression_name="binary_compression",
                rerank_with_original_vectors=None,
                default_oversampling=None,
                truncation_dimension=1024,
                rescoring_options=RescoringOptions(
                    enable_rescoring=False,
                    rescore_storage_method=VectorSearchCompressionRescoreStorageMethod.DISCARD_ORIGINALS,
                ),
            )
        ],
        profiles=[
            VectorSearchProfile(
                name="embedding_profile", algorithm_configuration_name="hnsw_config", compression_name="binary_compression"
            )
        ]
    ),
)

index_client.create_index(index)

# %% [markdown]
# ### **SCENARIOS**

# %%
INDEX_PREFIX = "compression-test"

scenarios = [
    {
        "name": "baseline",
        "compression_type": None,
        "truncate_dims": None,
        "discard_originals": False,
        "stored_embedding": True,
        "description": "Baseline configuration without compression"
    },
    {
        "name": "baseline-s",
        "compression_type": None,
        "truncate_dims": None,
        "discard_originals": False,
        "stored_embedding": False,
        "description": "Baseline configuration without compression, with stored=False "
    },
    {
        "name": "scalar-full",
        "compression_type": "scalar",
        "truncate_dims": None,
        "discard_originals": False,
        "stored_embedding": False,
        "description": "Scalar quantization (int8) with full dimensions, preserved originals"
    },
    {
        "name": "scalar-truncated-1024",
        "compression_type": "scalar",
        "truncate_dims": 1024,
        "discard_originals": False,
        "stored_embedding": False,
        "description": "Scalar quantization (int8) with 1024 dimensions, preserved originals"
    },
    {
        "name": "scalar-truncated-1024-discard",
        "compression_type": "scalar",
        "truncate_dims": 1024,
        "discard_originals": True,
        "stored_embedding": False,
        "description": "Scalar quantization (int8) with 1024 dimensions, discarded originals"
    },
    {
        "name": "binary-full",
        "compression_type": "binary",
        "truncate_dims": None,
        "discard_originals": False,
        "stored_embedding": False,
        "description": "Binary quantization with full dimensions, preserved originals"
    },
    {
        "name": "binary-truncated-1024",
        "compression_type": "binary",
        "truncate_dims": 1024,
        "discard_originals": False,
        "stored_embedding": False,
        "description": "Binary quantization with 1024 dimensions, preserved originals"
    },
    {
        "name": "binary-truncated-1024-discard",
        "compression_type": "binary",
        "truncate_dims": 1024,
        "discard_originals": True,
        "stored_embedding": False,
        "description": "Binary quantization with 1024 dimensions, discarded originals"
    }
]

# %% [markdown]
# ### **AZURE AI SEARCH INDEXER MANAGER CLASS**

# %%
class AzureSearchIndexManager:
    def __init__(self, service_endpoint: str, credential: str, index_name_prefix: str, vector_dimensions: int):
        self.client = SearchIndexClient(endpoint=service_endpoint, credential=credential)
        self.index_name_prefix = index_name_prefix
        self.vector_dimensions = vector_dimensions

    def _create_base_fields(self, stored_embedding=True):
        return [
            SimpleField(name="id", type=SearchFieldDataType.String, key=True),
            SearchField(name="title", type=SearchFieldDataType.String, searchable=True),
            SearchField(name="content", type=SearchFieldDataType.String, searchable=True),
            SearchField(
                name="embedding",
                type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
                searchable=True,
                vector_search_dimensions=self.vector_dimensions,
                vector_search_profile_name="default-profile",
                stored=stored_embedding,
            ),
        ]

    def _create_compression_config(
        self,
        config_type: str,
        truncate_dims: int = None,
        discard_originals: bool = False,
        oversample_ratio: int = 10,
    ):
        """
        Creates a compression configuration based on the scenario.
        """
        compression_name = f"{config_type}-compression"

        # Determine the storage method based on whether originals are discarded
        rescore_storage_method = (
            VectorSearchCompressionRescoreStorageMethod.DISCARD_ORIGINALS
            if discard_originals
            else VectorSearchCompressionRescoreStorageMethod.PRESERVE_ORIGINALS
        )

        # Enable rescoring only if originals are preserved
        enable_rescoring = not discard_originals

        # Configure rescoring options
        rescoring_options = RescoringOptions(
            enable_rescoring=enable_rescoring,
            default_oversampling=oversample_ratio if enable_rescoring else None,
            rescore_storage_method=rescore_storage_method,
        )

        # Base parameters for compression
        base_params = {
            "compression_name": compression_name,
            "rescoring_options": rescoring_options,
            # Explicitly set deprecated parameters to None
            "rerank_with_original_vectors": None,
            "default_oversampling": None,
        }

        # Add truncation dimension if specified
        if truncate_dims:
            base_params["truncation_dimension"] = truncate_dims

        # Create the appropriate compression object
        if config_type == "scalar":
            compression = ScalarQuantizationCompression(
                parameters=ScalarQuantizationParameters(quantized_data_type="int8"),
                **base_params,
            )
        elif config_type == "binary":
            compression = BinaryQuantizationCompression(
                **base_params,
            )
        else:
            compression = None

        return compression

    def _create_vector_search_config(self, compression_config=None):
        """
        Creates the VectorSearch configuration, including algorithm and compression settings.
        """
        # Define the HNSW algorithm configuration
        algorithm_config = HnswAlgorithmConfiguration(
            name="hnsw-config",
            kind="hnsw",
            parameters=HnswParameters(
                m=4,
                ef_construction=400,
                ef_search=500,
                metric="cosine"
            )
        )

        # Define the VectorSearchProfile
        profiles = [
            VectorSearchProfile(
                name="default-profile",
                algorithm_configuration_name=algorithm_config.name,
                compression_name=compression_config.compression_name if compression_config else None,
            )
        ]

        # Assemble the VectorSearch configuration
        vector_search = VectorSearch(
            profiles=profiles,
            algorithms=[algorithm_config],
            compressions=[compression_config] if compression_config else None,
        )

        return vector_search

    def create_index(self, scenario: dict):
        """
        Creates or updates an index based on the provided scenario.
        """
        index_name = f"{self.index_name_prefix}-{scenario['name']}"

        # Use the 'stored_embedding' value from the scenario
        stored_embedding = scenario.get('stored_embedding', True)

        # Create base fields with the stored_embedding flag
        fields = self._create_base_fields(stored_embedding=stored_embedding)

        # Create compression configuration if specified
        compression_config = None
        if scenario["compression_type"]:
            compression_config = self._create_compression_config(
                config_type=scenario["compression_type"],
                truncate_dims=scenario.get("truncate_dims"),
                discard_originals=scenario.get("discard_originals", False),
            )

        # Create vector search configuration
        vector_search = self._create_vector_search_config(compression_config)

        # Define the SearchIndex
        index = SearchIndex(
            name=index_name,
            fields=fields,
            vector_search=vector_search,
        )

        # Create or update the index
        try:
            self.client.create_or_update_index(index)
        except ResourceExistsError:
            print(f"Index {index_name} already exists.")
        except Exception as e:
            if e.message and "already exists" in e.message:
                print(f"Index {index_name} already exists.")
            else:
                print(f"Error creating index {index_name}: {type(e)} - {str(e)}")
    
        # Return the index name
        return index_name

# %%
manager = AzureSearchIndexManager(
    service_endpoint=AZURE_AI_SEARCH_BASIC_ENDPOINT,
    credential=AzureKeyCredential(AZURE_AI_SEARCH_BASIC_API_KEY),
    index_name_prefix=INDEX_PREFIX,
    vector_dimensions=3072)

# %%
# Create all index configurations
created_indexes = []
for scenario in scenarios:
    try:
        index_name = manager.create_index(scenario)
        created_indexes.append({
            "index_name": index_name,
            "configuration": scenario["description"]
        })
    except Exception as e:
        print(f"Error creating index for scenario {scenario['name']}: {str(e)}")

# Display created indexes
if len(created_indexes) > 0:
    print("\nCreated Indexes:")
    tabulate(created_indexes, headers="keys", tablefmt="html")
else:
    print("\nNo indexes were created successfully.")
# Out:
# Created Indexes:

# %%
ds = load_dataset(
    "Qdrant/dbpedia-entities-openai3-text-embedding-3-large-3072-1M",
    streaming=True,
    split='train'
)

# Select only needed columns
ds = ds.select_columns(["_id", "title", "text", "text-embedding-3-large-3072-embedding"])

# Take first 100K examples
print("Taking first 100K examples...")
data = []
for i, example in enumerate(ds):
    if i >= 100000:
        break
    data.append(example)

# Convert to Arrow table and save to parquet
print("Converting to parquet...")
output_file = "dbpedia_100k.parquet"
table = pa.Table.from_pylist(data)  # Using pa.Table instead of pq.Table
pq.write_table(
    table,
    output_file,
    compression='snappy'  # Good balance of compression and speed
)

print(f"Dataset saved to {output_file}")

# Verify the saved file
table = pq.read_table(output_file)
print(f"\nSaved dataset shape: {table.num_rows} rows × {table.num_columns} columns")
print("Columns:", table.column_names)
# Out:
# c:\Users\orevi489\Desktop\Proyectos\Personales\AzureAI\project_azure_ai_search_01\.venv\Lib\site-packages\huggingface_hub\file_download.py:120: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\orevi489\.cache\huggingface\hub\datasets--Qdrant--dbpedia-entities-openai3-text-embedding-3-large-3072-1M. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Taking first 100K examples...
# Converting to parquet...
# Dataset saved to dbpedia_100k.parquet
#
# Saved dataset shape: 100000 rows × 4 columns
# Columns: ['_id', 'title', 'text', 'text-embedding-3-large-3072-embedding']

# %%
# Read the parquet file
table = pq.read_table("./dbpedia_100k.parquet")

# Convert first row to the exact format we need
first_doc = {
    "id": str(table['_id'][0].as_py()),
    "title": table['title'][0].as_py(),
    "content": table['text'][0].as_py(),
    "embedding": table['text-embedding-3-large-3072-embedding'][0].as_py()
}

# Print info about the dataset
print("Dataset Information:")
print(f"Total number of rows: {table.num_rows}")
print(f"Columns: {table.column_names}")
print("\nFirst document structure:")
#print(json.dumps(first_doc, indent=2, default=str))

# Print some basic stats about the data
print("\nData Statistics:")
print(f"Embedding dimension: {len(first_doc['embedding'])}")
print(f"Average title length: {sum(len(str(title)) for title in table['title']) / table.num_rows:.1f} characters")
print(f"Average text length: {sum(len(str(text)) for text in table['text']) / table.num_rows:.1f} characters")

# Verify there are no null values
print("\nChecking for null values:")
for column in table.column_names:
    null_count = table[column].null_count
    print(f"{column}: {null_count} null values")
# Out:
# Dataset Information:
# Total number of rows: 100000
# Columns: ['_id', 'title', 'text', 'text-embedding-3-large-3072-embedding']
#
# First document structure:
#
# Data Statistics:
# Embedding dimension: 3072
# Average title length: 18.4 characters
# Average text length: 326.0 characters
#
# Checking for null values:
# _id: 0 null values
# title: 0 null values
# text: 0 null values
# text-embedding-3-large-3072-embedding: 0 null values

# %%
def chunk_list(lst: List[Any], chunk_size: int) -> List[List[Any]]:
    """Split a list into chunks of specified size."""
    return [lst[i : i + chunk_size] for i in range(0, len(lst), chunk_size)]

def encode_key(key: str) -> str:
    """Encode key to be Azure Search compatible using URL-safe base64."""
    return base64.urlsafe_b64encode(key.encode()).decode()

def prepare_documents(table) -> List[Dict]:
    """
    Convert Arrow table to list of documents with base64 encoded IDs.
    """
    documents = []
    total_rows = table.num_rows

    print(f"Converting {total_rows} rows to documents...")
    for i in range(total_rows):
        # Encode the ID to make it Azure Search compatible
        original_id = str(table["_id"][i].as_py())
        encoded_id = encode_key(original_id)

        document = {
            "id": encoded_id,
            "title": table["title"][i].as_py(),
            "content": table["text"][i].as_py(),
            "embedding": table["text-embedding-3-large-3072-embedding"][i].as_py(),
        }
        documents.append(document)

        if i % 1000 == 0:  # Progress indicator
            print(f"Processed {i}/{total_rows} documents...")

    print("Document conversion complete")

    # Print first document as sample (including both original and encoded ID)
    print("\nSample document format:")
    sample_doc = documents[0].copy()
    print("Original ID:", original_id)
    print("Encoded ID:", sample_doc["id"])
    print(json.dumps(sample_doc, indent=2, default=str))

    return documents

def upload_to_search(
    documents: List[Dict],
    endpoint: str,
    index_name: str,
    credential,
    batch_size: int = 100,
) -> None:
    """
    Upload documents to Azure Search index using manual batching.
    """
    # Create search client
    search_client = SearchClient(
        endpoint=endpoint, index_name=index_name, credential=credential
    )

    total_docs = len(documents)
    print(f"\nStarting upload to index: {index_name} at {datetime.now()}")
    print(f"Total documents to upload: {total_docs}")
    start_time = datetime.now()

    # Split documents into batches
    batches = chunk_list(documents, batch_size)
    total_batches = len(batches)

    successful_docs = 0
    failed_docs = 0

    try:
        for batch_num, batch in enumerate(batches, 1):
            max_retries = 3
            retry_count = 0

            while retry_count < max_retries:
                try:
                    results = search_client.upload_documents(documents=batch)

                    # Count successes and failures
                    for result in results:
                        if result.succeeded:
                            successful_docs += 1
                        else:
                            failed_docs += 1
                            print(
                                f"Failed to upload document {result.key}: {result.error}"
                            )

                    elapsed_time = datetime.now() - start_time
                    print(
                        f"Index {index_name}: Processed batch {batch_num}/{total_batches} "
                        f"({successful_docs}/{total_docs} docs). "
                        f"Elapsed time: {elapsed_time}"
                    )

                    # Short pause between batches to prevent throttling
                    time.sleep(0.25)
                    break  # Success - exit retry loop

                except Exception as e:
                    retry_count += 1
                    if retry_count == max_retries:
                        print(
                            f"Failed to upload batch after {max_retries} attempts: {str(e)}"
                        )
                        failed_docs += len(batch)
                    else:
                        print(
                            f"Retry {retry_count}/{max_retries} after error: {str(e)}"
                        )
                        time.sleep(2**retry_count)  # Exponential backoff

        total_time = datetime.now() - start_time
        print(f"\nUpload to {index_name} completed:")
        print(f"Successfully uploaded: {successful_docs} documents")
        print(f"Failed to upload: {failed_docs} documents")
        print(f"Total time: {total_time}")

        # Verify final count
        result = search_client.search("*", top=0)
        final_count = result.get_count()
        print(f"Final document count in index: {final_count}")

    except Exception as e:
        print(f"Fatal error during upload to {index_name}: {str(e)}")
        raise

def upload_to_all_indexes(
    documents: List[Dict],
    endpoint: str,
    index_prefix: str,
    scenarios: list,
    credential: AzureKeyCredential,
    batch_size: int = 100,
) -> None:
    """
    Upload documents to all indexes sequentially.
    """
    total_start_time = datetime.now()

    for i, scenario in enumerate(scenarios, 1):
        index_name = f"{index_prefix}-{scenario['name']}"
        print(f"\nProcessing index {i} of {len(scenarios)}: {index_name}")
        upload_to_search(
            documents=documents,
            endpoint=endpoint,
            index_name=index_name,
            credential=credential,
            batch_size=batch_size,
        )

    total_time = datetime.now() - total_start_time
    print(f"\nCompleted all uploads. Total time: {total_time}")

# %%
scenarios = [
    {
        "name": "scalar-truncated-1024",
        "compression_type": "scalar",
        "truncate_dims": 1024,
        "discard_originals": False,
        "stored_embedding": False,
        "description": "Scalar quantization (int8) with 1024 dimensions, preserved originals"
    },
    {
        "name": "scalar-truncated-1024-discard",
        "compression_type": "scalar",
        "truncate_dims": 1024,
        "discard_originals": True,
        "stored_embedding": False,
        "description": "Scalar quantization (int8) with 1024 dimensions, discarded originals"
    },
    {
        "name": "binary-full",
        "compression_type": "binary",
        "truncate_dims": None,
        "discard_originals": False,
        "stored_embedding": False,
        "description": "Binary quantization with full dimensions, preserved originals"
    },
    {
        "name": "binary-truncated-1024",
        "compression_type": "binary",
        "truncate_dims": 1024,
        "discard_originals": False,
        "stored_embedding": False,
        "description": "Binary quantization with 1024 dimensions, preserved originals"
    },
    {
        "name": "binary-truncated-1024-discard",
        "compression_type": "binary",
        "truncate_dims": 1024,
        "discard_originals": True,
        "stored_embedding": False,
        "description": "Binary quantization with 1024 dimensions, discarded originals"
    }
]

# %%
# Usage:
print("Loading parquet file...")
table = pq.read_table("./dbpedia_100k.parquet")
print(f"Loaded {table.num_rows} rows")

# Prepare documents once
documents = prepare_documents(table)

# Create credential and upload to all indexes
upload_to_all_indexes(
    documents=documents,
    endpoint=AZURE_AI_SEARCH_BASIC_ENDPOINT,
    index_prefix=INDEX_PREFIX,
    scenarios=scenarios,
    credential=AzureKeyCredential(AZURE_AI_SEARCH_BASIC_API_KEY),
    batch_size=100
)
# Out:
# Loading parquet file...
# Loaded 100000 rows
# Converting 100000 rows to documents...
# Processed 0/100000 documents...
# Processed 1000/100000 documents...
# Processed 2000/100000 documents...
# Processed 3000/100000 documents...
# Processed 4000/100000 documents...
# Processed 5000/100000 documents...
# Processed 6000/100000 documents...
# Processed 7000/100000 documents...
# Processed 8000/100000 documents...
# Processed 9000/100000 documents...
# Processed 10000/100000 documents...
# Processed 11000/100000 documents...
# Processed 12000/100000 documents...
# Processed 13000/100000 documents...
# Processed 14000/100000 documents...
# Processed 15000/100000 documents...
# Processed 16000/100000 documents...
# Processed 17000/100000 documents...
# Processed 18000/100000 documents...
# Processed 19000/100000 documents...
# Processed 20000/100000 documents...
# Processed 21000/100000 documents...
# Processed 22000/100000 documents...
# Processed 23000/100000 documents...
# Processed 24000/100000 documents...
# Processed 25000/100000 documents...
# Processed 26000/100000 documents...
# Processed 27000/100000 documents...
# Processed 28000/100000 documents...
# Processed 29000/100000 documents...
# Processed 30000/100000 documents...
# Processed 31000/100000 documents...
# Processed 32000/100000 documents...
# Processed 33000/100000 documents...
# Processed 34000/100000 documents...
# Processed 35000/100000 documents...
# Processed 36000/100000 documents...
# Processed 37000/100000 documents...
# Processed 38000/100000 documents...
# Processed 39000/100000 documents...
# Processed 40000/100000 documents...
# Processed 41000/100000 documents...
# Processed 42000/100000 documents...
# Processed 43000/100000 documents...
# Processed 44000/100000 documents...
# Processed 45000/100000 documents...
# Processed 46000/100000 documents...
# Processed 47000/100000 documents...
# Processed 48000/100000 documents...
# Processed 49000/100000 documents...
# Processed 50000/100000 documents...
# Processed 51000/100000 documents...
# Processed 52000/100000 documents...
# Processed 53000/100000 documents...
# Processed 54000/100000 documents...
# Processed 55000/100000 documents...
# Processed 56000/100000 documents...
# Processed 57000/100000 documents...
# Processed 58000/100000 documents...
# Processed 59000/100000 documents...
# Processed 60000/100000 documents...
# Processed 61000/100000 documents...
# Processed 62000/100000 documents...
# Processed 63000/100000 documents...
# Processed 64000/100000 documents...
# Processed 65000/100000 documents...
# Processed 66000/100000 documents...
# Processed 67000/100000 documents...
# Processed 68000/100000 documents...
# Processed 69000/100000 documents...
# Processed 70000/100000 documents...
# Processed 71000/100000 documents...
# Processed 72000/100000 documents...
# Processed 73000/100000 documents...
# Processed 74000/100000 documents...
# Processed 75000/100000 documents...
# Processed 76000/100000 documents...
# Processed 77000/100000 documents...
# Processed 78000/100000 documents...
# Processed 79000/100000 documents...
# Processed 80000/100000 documents...
# Processed 81000/100000 documents...
# Processed 82000/100000 documents...
# Processed 83000/100000 documents...
# Processed 84000/100000 documents...
# Processed 85000/100000 documents...
# Processed 86000/100000 documents...
# Processed 87000/100000 documents...
# Processed 88000/100000 documents...
# Processed 89000/100000 documents...
# Processed 90000/100000 documents...
# Processed 91000/100000 documents...
# Processed 92000/100000 documents...
# Processed 93000/100000 documents...
# Processed 94000/100000 documents...
# Processed 95000/100000 documents...
# Processed 96000/100000 documents...
# Processed 97000/100000 documents...
# Processed 98000/100000 documents...
# Processed 99000/100000 documents...
# Document conversion complete
#
# Sample document format:
# Original ID: <dbpedia:Matías_Silvestre>
# Encoded ID: PGRicGVkaWE6UGFyYWJvbGljX3JlZmxlY3Rvcj4=
# {
#   "id": "PGRicGVkaWE6UGFyYWJvbGljX3JlZmxlY3Rvcj4=",
#   "title": "Parabolic reflector",
#   "content": "A parabolic (or paraboloid or paraboloidal) reflector (or dish or mirror) is a reflective surface used to collect or project energy such as light, sound, or radio waves. Its shape is part of a circular paraboloid, that is, the surface generated by a parabola revolving around its axis. The parabolic reflector transforms an incoming plane wave traveling along the axis into a spherical wave converging toward the focus.",
#   "embedding": [
#     -0.022388368844985962,
#     0.028537113219499588,
#     -0.017491688951849937,
#     -0.01533466950058937,
#     -0.03451230376958847,
#     0.0162644200026989,
#     -0.020231351256370544,
#     -0.012743767350912094,
#     -0.032082557678222656,
#     0.0037468906957656145,
#     -0.003864658996462822,
#     0.004292343743145466,
#     0.007035105023533106,
#     -0.03314867243170738,
#     0.0015302128158509731,
#     0.027074307203292847,
#     0.02011978067457676,
#     -0.0034772634971886873,
#     0.02200407348573208,
#     -0.008039234206080437,
#     -0.0002686588850338012,
#     -0.037809815257787704,
#     -0.06664445251226425,
#     -0.017181772738695145,
#     -0.01554541289806366,
#     0.015322272665798664,
#     0.026256127282977104,
#     -0.03215693682432175,
#     -0.0459420271217823,
#     -0.02085118368268013,
#     0.05697505548596382,
#     0.00940906535834074,
#     0.008659067563712597,
#     -0.02898339368402958,
#     -0.03329743072390556,
#     -0.013140460476279259,
#     -0.025834642350673676,
#     -0.04946267604827881,
#     -0.026206541806459427,
#     0.0009258756181225181,
#     -0.012285090982913971,
#     0.011095011606812477,
#     -0.018656974658370018,
#     0.0036694116424769163,
#     -0.02071482129395008,
#     0.030842892825603485,
#     -0.0012753064511343837,
#     0.023813985288143158,
#     -0.017900777980685234,
#     -0.031066032126545906,
#     0.021991675719618797,
#     0.00046642436063848436,
#     -0.014095003716647625,
#     0.009582619182765484,
#     0.000968489155638963,
#     -0.010227245278656483,
#     0.0066879987716674805,
#     -0.008590886369347572,
#     -0.010227245278656483,
#     0.006151842884719372,
#     0.016462765634059906,
#     0.019425567239522934,
#     0.018619785085320473,
#     -0.017628051340579987,
#     0.0026063979603350163,
#     0.012551619671285152,
#     -0.008225184865295887,
#     -0.010946251451969147,
#     -0.006892543286085129,
#     -0.007227253168821335,
#     -0.009681791998445988,
#     -0.00788427609950304,
#     -0.0015131674008443952,
#     0.013214840553700924,
#     -0.0020934860222041607,
#     0.008981380611658096,
#     -0.015619792975485325,
#     0.007896672934293747,
#     0.008522704243659973,
#     -0.01264459453523159,
#     0.02826438657939434,
#     -0.010400798171758652,
#     -0.010072287172079086,
#     -0.005854323040693998,
#     0.003920443821698427,
#     -0.007295434828847647,
#     0.005181804299354553,
#     -0.030347026884555817,
#     -0.017392516136169434,
#     0.0038584608118981123,
#     0.009483445435762405,
#     0.033743713051080704,
#     -0.008603282272815704,
#     0.0006519868620671332,
#     0.0063099004328250885,
#     -0.00040056710713543,
#     0.021483413875102997,
#     -0.002665282227098942,
#     -0.003988625481724739,
#     -0.0010730859357863665,
# ...
# Index compression-test-binary-truncated-1024-discard: Processed batch 879/1000 (87900/100000 docs). Elapsed time: 0:49:48.039424
# Index compression-test-binary-truncated-1024-discard: Processed batch 880/1000 (88000/100000 docs). Elapsed time: 0:49:56.965205
# Index compression-test-binary-truncated-1024-discard: Processed batch 881/1000 (88100/100000 docs). Elapsed time: 0:50:01.472015
# Index compression-test-binary-truncated-1024-discard: Processed batch 882/1000 (88200/100000 docs). Elapsed time: 0:50:05.472816
# Index compression-test-binary-truncated-1024-discard: Processed batch 883/1000 (88300/100000 docs). Elapsed time: 0:50:10.200191
# Index compression-test-binary-truncated-1024-discard: Processed batch 884/1000 (88400/100000 docs). Elapsed time: 0:50:14.246988
# Index compression-test-binary-truncated-1024-discard: Processed batch 885/1000 (88500/100000 docs). Elapsed time: 0:50:18.664314
# Index compression-test-binary-truncated-1024-discard: Processed batch 886/1000 (88600/100000 docs). Elapsed time: 0:50:24.718488
# Index compression-test-binary-truncated-1024-discard: Processed batch 887/1000 (88700/100000 docs). Elapsed time: 0:50:27.257093
# Index compression-test-binary-truncated-1024-discard: Processed batch 888/1000 (88800/100000 docs). Elapsed time: 0:50:29.091068
# Index compression-test-binary-truncated-1024-discard: Processed batch 889/1000 (88900/100000 docs). Elapsed time: 0:50:32.204313
# Index compression-test-binary-truncated-1024-discard: Processed batch 890/1000 (89000/100000 docs). Elapsed time: 0:50:39.520672
# Index compression-test-binary-truncated-1024-discard: Processed batch 891/1000 (89100/100000 docs). Elapsed time: 0:50:41.666886
# Index compression-test-binary-truncated-1024-discard: Processed batch 892/1000 (89200/100000 docs). Elapsed time: 0:50:47.274554
# Index compression-test-binary-truncated-1024-discard: Processed batch 893/1000 (89300/100000 docs). Elapsed time: 0:50:51.739300
# Index compression-test-binary-truncated-1024-discard: Processed batch 894/1000 (89400/100000 docs). Elapsed time: 0:50:56.336178
# Index compression-test-binary-truncated-1024-discard: Processed batch 895/1000 (89500/100000 docs). Elapsed time: 0:51:00.693620
# Index compression-test-binary-truncated-1024-discard: Processed batch 896/1000 (89600/100000 docs). Elapsed time: 0:51:04.754862
# Index compression-test-binary-truncated-1024-discard: Processed batch 897/1000 (89700/100000 docs). Elapsed time: 0:51:10.283006
# Index compression-test-binary-truncated-1024-discard: Processed batch 898/1000 (89800/100000 docs). Elapsed time: 0:51:12.318610
# Index compression-test-binary-truncated-1024-discard: Processed batch 899/1000 (89900/100000 docs). Elapsed time: 0:51:15.385837
# Index compression-test-binary-truncated-1024-discard: Processed batch 900/1000 (90000/100000 docs). Elapsed time: 0:51:18.323334
# Index compression-test-binary-truncated-1024-discard: Processed batch 901/1000 (90100/100000 docs). Elapsed time: 0:51:21.070125
# Index compression-test-binary-truncated-1024-discard: Processed batch 902/1000 (90200/100000 docs). Elapsed time: 0:51:26.546574
# Index compression-test-binary-truncated-1024-discard: Processed batch 903/1000 (90300/100000 docs). Elapsed time: 0:51:32.417112
# Index compression-test-binary-truncated-1024-discard: Processed batch 904/1000 (90400/100000 docs). Elapsed time: 0:51:36.601400
# Index compression-test-binary-truncated-1024-discard: Processed batch 905/1000 (90500/100000 docs). Elapsed time: 0:51:41.161689
# Index compression-test-binary-truncated-1024-discard: Processed batch 906/1000 (90600/100000 docs). Elapsed time: 0:51:45.552232
# Index compression-test-binary-truncated-1024-discard: Processed batch 907/1000 (90700/100000 docs). Elapsed time: 0:51:50.201083
# Index compression-test-binary-truncated-1024-discard: Processed batch 908/1000 (90800/100000 docs). Elapsed time: 0:51:56.411481
# Index compression-test-binary-truncated-1024-discard: Processed batch 909/1000 (90900/100000 docs). Elapsed time: 0:51:59.496520
# Index compression-test-binary-truncated-1024-discard: Processed batch 910/1000 (91000/100000 docs). Elapsed time: 0:52:02.902624
# Index compression-test-binary-truncated-1024-discard: Processed batch 911/1000 (91100/100000 docs). Elapsed time: 0:52:08.714316
# Index compression-test-binary-truncated-1024-discard: Processed batch 912/1000 (91200/100000 docs). Elapsed time: 0:52:14.272228
# Index compression-test-binary-truncated-1024-discard: Processed batch 913/1000 (91300/100000 docs). Elapsed time: 0:52:20.280374
# Index compression-test-binary-truncated-1024-discard: Processed batch 914/1000 (91400/100000 docs). Elapsed time: 0:52:25.024699
# Index compression-test-binary-truncated-1024-discard: Processed batch 915/1000 (91500/100000 docs). Elapsed time: 0:52:29.383468
# Index compression-test-binary-truncated-1024-discard: Processed batch 916/1000 (91600/100000 docs). Elapsed time: 0:52:33.766103
# Index compression-test-binary-truncated-1024-discard: Processed batch 917/1000 (91700/100000 docs). Elapsed time: 0:52:39.911329
# Index compression-test-binary-truncated-1024-discard: Processed batch 918/1000 (91800/100000 docs). Elapsed time: 0:52:42.421700
# Index compression-test-binary-truncated-1024-discard: Processed batch 919/1000 (91900/100000 docs). Elapsed time: 0:52:44.317850
# Index compression-test-binary-truncated-1024-discard: Processed batch 920/1000 (92000/100000 docs). Elapsed time: 0:52:47.001919
# Index compression-test-binary-truncated-1024-discard: Processed batch 921/1000 (92100/100000 docs). Elapsed time: 0:52:49.415987
# Index compression-test-binary-truncated-1024-discard: Processed batch 922/1000 (92200/100000 docs). Elapsed time: 0:52:56.501981
# Index compression-test-binary-truncated-1024-discard: Processed batch 923/1000 (92300/100000 docs). Elapsed time: 0:53:00.864875
# Index compression-test-binary-truncated-1024-discard: Processed batch 924/1000 (92400/100000 docs). Elapsed time: 0:53:06.964698
# Index compression-test-binary-truncated-1024-discard: Processed batch 925/1000 (92500/100000 docs). Elapsed time: 0:53:11.753848
# Index compression-test-binary-truncated-1024-discard: Processed batch 926/1000 (92600/100000 docs). Elapsed time: 0:53:16.028023
# Index compression-test-binary-truncated-1024-discard: Processed batch 927/1000 (92700/100000 docs). Elapsed time: 0:53:20.150011
# Index compression-test-binary-truncated-1024-discard: Processed batch 928/1000 (92800/100000 docs). Elapsed time: 0:53:26.077211
# Index compression-test-binary-truncated-1024-discard: Processed batch 929/1000 (92900/100000 docs). Elapsed time: 0:53:28.889124
# Index compression-test-binary-truncated-1024-discard: Processed batch 930/1000 (93000/100000 docs). Elapsed time: 0:53:31.429458
# Index compression-test-binary-truncated-1024-discard: Processed batch 931/1000 (93100/100000 docs). Elapsed time: 0:53:33.831258
# Index compression-test-binary-truncated-1024-discard: Processed batch 932/1000 (93200/100000 docs). Elapsed time: 0:53:42.245240
# Index compression-test-binary-truncated-1024-discard: Processed batch 933/1000 (93300/100000 docs). Elapsed time: 0:53:45.933251
# Index compression-test-binary-truncated-1024-discard: Processed batch 934/1000 (93400/100000 docs). Elapsed time: 0:53:52.426901
# Index compression-test-binary-truncated-1024-discard: Processed batch 935/1000 (93500/100000 docs). Elapsed time: 0:53:55.465614
# Index compression-test-binary-truncated-1024-discard: Processed batch 936/1000 (93600/100000 docs). Elapsed time: 0:53:57.574118
# Index compression-test-binary-truncated-1024-discard: Processed batch 937/1000 (93700/100000 docs). Elapsed time: 0:54:02.222974
# Index compression-test-binary-truncated-1024-discard: Processed batch 938/1000 (93800/100000 docs). Elapsed time: 0:54:06.923218
# Index compression-test-binary-truncated-1024-discard: Processed batch 939/1000 (93900/100000 docs). Elapsed time: 0:54:13.037128
# Index compression-test-binary-truncated-1024-discard: Processed batch 940/1000 (94000/100000 docs). Elapsed time: 0:54:15.907210
# Index compression-test-binary-truncated-1024-discard: Processed batch 941/1000 (94100/100000 docs). Elapsed time: 0:54:19.309882
# Index compression-test-binary-truncated-1024-discard: Processed batch 942/1000 (94200/100000 docs). Elapsed time: 0:54:22.163345
# Index compression-test-binary-truncated-1024-discard: Processed batch 943/1000 (94300/100000 docs). Elapsed time: 0:54:24.619507
# Index compression-test-binary-truncated-1024-discard: Processed batch 944/1000 (94400/100000 docs). Elapsed time: 0:54:30.511227
# Index compression-test-binary-truncated-1024-discard: Processed batch 945/1000 (94500/100000 docs). Elapsed time: 0:54:33.359914
# Index compression-test-binary-truncated-1024-discard: Processed batch 946/1000 (94600/100000 docs). Elapsed time: 0:54:35.777836
# Index compression-test-binary-truncated-1024-discard: Processed batch 947/1000 (94700/100000 docs). Elapsed time: 0:54:41.984987
# Index compression-test-binary-truncated-1024-discard: Processed batch 948/1000 (94800/100000 docs). Elapsed time: 0:54:46.590913
# Index compression-test-binary-truncated-1024-discard: Processed batch 949/1000 (94900/100000 docs). Elapsed time: 0:54:52.554286
# Index compression-test-binary-truncated-1024-discard: Processed batch 950/1000 (95000/100000 docs). Elapsed time: 0:54:58.755953
# Index compression-test-binary-truncated-1024-discard: Processed batch 951/1000 (95100/100000 docs). Elapsed time: 0:55:01.747393
# Index compression-test-binary-truncated-1024-discard: Processed batch 952/1000 (95200/100000 docs). Elapsed time: 0:55:06.389579
# Index compression-test-binary-truncated-1024-discard: Processed batch 953/1000 (95300/100000 docs). Elapsed time: 0:55:10.696754
# Index compression-test-binary-truncated-1024-discard: Processed batch 954/1000 (95400/100000 docs). Elapsed time: 0:55:17.566021
# Index compression-test-binary-truncated-1024-discard: Processed batch 955/1000 (95500/100000 docs). Elapsed time: 0:55:20.355850
# Index compression-test-binary-truncated-1024-discard: Processed batch 956/1000 (95600/100000 docs). Elapsed time: 0:55:22.618249
# Index compression-test-binary-truncated-1024-discard: Processed batch 957/1000 (95700/100000 docs). Elapsed time: 0:55:29.141036
# Index compression-test-binary-truncated-1024-discard: Processed batch 958/1000 (95800/100000 docs). Elapsed time: 0:55:31.940715
# Index compression-test-binary-truncated-1024-discard: Processed batch 959/1000 (95900/100000 docs). Elapsed time: 0:55:34.533151
# Index compression-test-binary-truncated-1024-discard: Processed batch 960/1000 (96000/100000 docs). Elapsed time: 0:55:40.949163
# Index compression-test-binary-truncated-1024-discard: Processed batch 961/1000 (96100/100000 docs). Elapsed time: 0:55:47.137117
# Index compression-test-binary-truncated-1024-discard: Processed batch 962/1000 (96200/100000 docs). Elapsed time: 0:55:50.370455
# Index compression-test-binary-truncated-1024-discard: Processed batch 963/1000 (96300/100000 docs). Elapsed time: 0:55:55.412432
# Index compression-test-binary-truncated-1024-discard: Processed batch 964/1000 (96400/100000 docs). Elapsed time: 0:55:57.537101
# Index compression-test-binary-truncated-1024-discard: Processed batch 965/1000 (96500/100000 docs). Elapsed time: 0:55:59.940359
# Index compression-test-binary-truncated-1024-discard: Processed batch 966/1000 (96600/100000 docs). Elapsed time: 0:56:06.697569
# Index compression-test-binary-truncated-1024-discard: Processed batch 967/1000 (96700/100000 docs). Elapsed time: 0:56:08.738705
# Index compression-test-binary-truncated-1024-discard: Processed batch 968/1000 (96800/100000 docs). Elapsed time: 0:56:12.518911
# Index compression-test-binary-truncated-1024-discard: Processed batch 969/1000 (96900/100000 docs). Elapsed time: 0:56:18.787001
# Index compression-test-binary-truncated-1024-discard: Processed batch 970/1000 (97000/100000 docs). Elapsed time: 0:56:23.223744
# Index compression-test-binary-truncated-1024-discard: Processed batch 971/1000 (97100/100000 docs). Elapsed time: 0:56:28.944718
# Index compression-test-binary-truncated-1024-discard: Processed batch 972/1000 (97200/100000 docs). Elapsed time: 0:56:31.014233
# Index compression-test-binary-truncated-1024-discard: Processed batch 973/1000 (97300/100000 docs). Elapsed time: 0:56:37.124311
# Index compression-test-binary-truncated-1024-discard: Processed batch 974/1000 (97400/100000 docs). Elapsed time: 0:56:39.484657
# Index compression-test-binary-truncated-1024-discard: Processed batch 975/1000 (97500/100000 docs). Elapsed time: 0:56:41.802509
# Index compression-test-binary-truncated-1024-discard: Processed batch 976/1000 (97600/100000 docs). Elapsed time: 0:56:46.583663
# Index compression-test-binary-truncated-1024-discard: Processed batch 977/1000 (97700/100000 docs). Elapsed time: 0:56:51.026476
# Index compression-test-binary-truncated-1024-discard: Processed batch 978/1000 (97800/100000 docs). Elapsed time: 0:56:55.992236
# Index compression-test-binary-truncated-1024-discard: Processed batch 979/1000 (97900/100000 docs). Elapsed time: 0:56:59.522129
# Index compression-test-binary-truncated-1024-discard: Processed batch 980/1000 (98000/100000 docs). Elapsed time: 0:57:01.695210
# Index compression-test-binary-truncated-1024-discard: Processed batch 981/1000 (98100/100000 docs). Elapsed time: 0:57:08.107977
# Index compression-test-binary-truncated-1024-discard: Processed batch 982/1000 (98200/100000 docs). Elapsed time: 0:57:12.333884
# Index compression-test-binary-truncated-1024-discard: Processed batch 983/1000 (98300/100000 docs). Elapsed time: 0:57:18.532982
# Index compression-test-binary-truncated-1024-discard: Processed batch 984/1000 (98400/100000 docs). Elapsed time: 0:57:24.655416
# Index compression-test-binary-truncated-1024-discard: Processed batch 985/1000 (98500/100000 docs). Elapsed time: 0:57:26.809032
# Index compression-test-binary-truncated-1024-discard: Processed batch 986/1000 (98600/100000 docs). Elapsed time: 0:57:28.943523
# Index compression-test-binary-truncated-1024-discard: Processed batch 987/1000 (98700/100000 docs). Elapsed time: 0:57:34.237786
# Index compression-test-binary-truncated-1024-discard: Processed batch 988/1000 (98800/100000 docs). Elapsed time: 0:57:38.279943
# Index compression-test-binary-truncated-1024-discard: Processed batch 989/1000 (98900/100000 docs). Elapsed time: 0:57:41.729331
# Index compression-test-binary-truncated-1024-discard: Processed batch 990/1000 (99000/100000 docs). Elapsed time: 0:57:43.999803
# Index compression-test-binary-truncated-1024-discard: Processed batch 991/1000 (99100/100000 docs). Elapsed time: 0:57:48.553755
# Index compression-test-binary-truncated-1024-discard: Processed batch 992/1000 (99200/100000 docs). Elapsed time: 0:57:55.119870
# Index compression-test-binary-truncated-1024-discard: Processed batch 993/1000 (99300/100000 docs). Elapsed time: 0:57:57.652616
# Index compression-test-binary-truncated-1024-discard: Processed batch 994/1000 (99400/100000 docs). Elapsed time: 0:58:00.583681
# Index compression-test-binary-truncated-1024-discard: Processed batch 995/1000 (99500/100000 docs). Elapsed time: 0:58:06.562069
# Index compression-test-binary-truncated-1024-discard: Processed batch 996/1000 (99600/100000 docs). Elapsed time: 0:58:12.976395
# Index compression-test-binary-truncated-1024-discard: Processed batch 997/1000 (99700/100000 docs). Elapsed time: 0:58:15.919863
# Index compression-test-binary-truncated-1024-discard: Processed batch 998/1000 (99800/100000 docs). Elapsed time: 0:58:19.337412
# Index compression-test-binary-truncated-1024-discard: Processed batch 999/1000 (99900/100000 docs). Elapsed time: 0:58:25.069754
# Index compression-test-binary-truncated-1024-discard: Processed batch 1000/1000 (100000/100000 docs). Elapsed time: 0:58:29.679004
#
# Upload to compression-test-binary-truncated-1024-discard completed:
# Successfully uploaded: 100000 documents
# Failed to upload: 0 documents
# Total time: 0:58:29.930098
# Final document count in index: None
#
# Completed all uploads. Total time: 4:51:46.578999

# %%
def bytes_to_mb(bytes):
    """Convert bytes to megabytes with 4 decimal places"""
    return round(bytes / (2**20), 4)

def get_index_sizes(
    endpoint: str,
    index_prefix: str,
    scenarios: list,
    credential,
    retry_attempts: int = 3
) -> None:
    """
    Get and print storage sizes for all indexes, with retry logic for eventual consistency.
    """
    # Create search index client
    search_index_client = SearchIndexClient(endpoint=endpoint, credential=credential)
    
    print("\nGathering index statistics...")
    print("Note: There may be delays in finding index statistics after document upload")
    print("Index statistics is not a real-time API\n")
    
    # Collect all index sizes with retries
    index_data = []
    for scenario in scenarios:
        index_name = f"{index_prefix}-{scenario['name']}"
        
        for attempt in range(retry_attempts):
            try:
                stats = search_index_client.get_index_statistics(index_name)
                storage_size = bytes_to_mb(stats["storage_size"])
                vector_size = bytes_to_mb(stats["vector_index_size"])
                total_size = storage_size + vector_size
                index_data.append({
                    'Index Name': index_name,
                    'Scenario': scenario['name'],
                    'Storage Size (MB)': storage_size,
                    'Vector Size (MB)': vector_size,
                    'Total Size (MB)': total_size,  # Added for sorting
                })
                break
            except Exception as e:
                if attempt == retry_attempts - 1:
                    print(f"Failed to get statistics for {index_name} after {retry_attempts} attempts: {str(e)}")
                else:
                    print(f"Retry {attempt + 1}/{retry_attempts} for {index_name}")
                    time.sleep(2 ** attempt)  # Exponential backoff
    
    # Find baseline storage and vector sizes
    baseline_entry = next((entry for entry in index_data if entry['Scenario'] == 'baseline'), None)
    if not baseline_entry:
        print("Baseline scenario not found.")
        return
    baseline_storage_size = baseline_entry['Storage Size (MB)']
    baseline_vector_size = baseline_entry['Vector Size (MB)']
    
    # Compute reduction percentages compared to baseline
    for entry in index_data:
        storage_reduction_pct = ((baseline_storage_size - entry['Storage Size (MB)']) / baseline_storage_size) * 100
        vector_reduction_pct = ((baseline_vector_size - entry['Vector Size (MB)']) / baseline_vector_size) * 100
        entry['Storage Reduction (%)'] = f"{storage_reduction_pct:.2f}"
        entry['Vector Reduction (%)'] = f"{vector_reduction_pct:.2f}"
    
    # Sort by total size
    index_data.sort(key=lambda x: x['Total Size (MB)'], reverse=True)
    
    # Prepare table headers and rows
    headers = [
        'Index Name', 'Scenario', 'Storage Size (MB)', 'Storage Reduction (%)',
        'Vector Size (MB)', 'Vector Reduction (%)'
    ]
    table_rows = [
        [
            entry['Index Name'],
            entry['Scenario'],
            f"{entry['Storage Size (MB)']:.4f}",
            entry['Storage Reduction (%)'],
            f"{entry['Vector Size (MB)']:.4f}",
            entry['Vector Reduction (%)']
        ]
        for entry in index_data
    ]
    
    # Print the table using tabulate
    return tabulate(table_rows, headers=headers, tablefmt="html")

# %%
# Get and print index sizes
get_index_sizes(
    endpoint=AZURE_AI_SEARCH_BASIC_ENDPOINT,
    index_prefix=INDEX_PREFIX,
    scenarios=scenarios,
    credential=AzureKeyCredential(AZURE_AI_SEARCH_BASIC_API_KEY)
)
# Out:
# Gathering index statistics...
# Note: There may be delays in finding index statistics after document upload
# Index statistics is not a real-time API
# '<table>\n<thead>\n<tr><th>Index Name                                    </th><th>Scenario                     </th><th style="text-align: right;">  Storage Size (MB)</th><th style="text-align: right;">  Storage Reduction (%)</th><th style="text-align: right;">  Vector Size (MB)</th><th style="text-align: right;">  Vector Reduction (%)</th></tr>\n</thead>\n<tbody>\n<tr><td>compression-test-baseline                     </td><td>baseline                     </td><td style="text-align: right;">           3812.89 </td><td style="text-align: right;">                   0   </td><td style="text-align: right;">         1177.15  </td><td style="text-align: right;">                  0   </td></tr>\n<tr><td>compression-test-baseline-s                   </td><td>baseline-s                   </td><td style="text-align: right;">           1310.77 </td><td style="text-align: right;">                  65.62</td><td style="text-align: right;">         1177.14  </td><td style="text-align: right;">                  0   </td></tr>\n<tr><td>compression-test-scalar-full                  </td><td>scalar-full                  </td><td style="text-align: right;">           1408.78 </td><td style="text-align: right;">                  63.05</td><td style="text-align: right;">          263.125 </td><td style="text-align: right;">                 77.65</td></tr>\n<tr><td>compression-test-scalar-truncated-1024        </td><td>scalar-truncated-1024        </td><td style="text-align: right;">           1410.47 </td><td style="text-align: right;">                  63.01</td><td style="text-align: right;">          103.542 </td><td style="text-align: right;">                 91.2 </td></tr>\n<tr><td>compression-test-binary-full                  </td><td>binary-full                  </td><td style="text-align: right;">           1347.72 </td><td style="text-align: right;">                  64.65</td><td style="text-align: right;">           41.8899</td><td style="text-align: right;">                 96.44</td></tr>\n<tr><td>compression-test-binary-truncated-1024        </td><td>binary-truncated-1024        </td><td style="text-align: right;">           1323.31 </td><td style="text-align: right;">                  65.29</td><td style="text-align: right;">           17.4655</td><td style="text-align: right;">                 98.52</td></tr>\n<tr><td>compression-test-scalar-truncated-1024-discard</td><td>scalar-truncated-1024-discard</td><td style="text-align: right;">            232.35 </td><td style="text-align: right;">                  93.91</td><td style="text-align: right;">          102.903 </td><td style="text-align: right;">                 91.26</td></tr>\n<tr><td>compression-test-binary-truncated-1024-discard</td><td>binary-truncated-1024-discard</td><td style="text-align: right;">            145.827</td><td style="text-align: right;">                  96.18</td><td style="text-align: right;">           17.4543</td><td style="text-align: right;">                 98.52</td></tr>\n</tbody>\n</table>'

# %%
search_index_client_statistics = SearchIndexClient(endpoint=AZURE_AI_SEARCH_BASIC_ENDPOINT, credential=AzureKeyCredential(AZURE_AI_SEARCH_BASIC_API_KEY))

# %%
search_index_client_statistics.get_index_statistics('compression-test-baseline')
# Out:
# {'document_count': 100000,
#  'storage_size': 3998108668,
#  'vector_index_size': 1234328600}

# %%
if AZURE_OPENAI_API_KEY:
    openai_client = AzureOpenAI(
        api_key=AZURE_OPENAI_API_KEY,
        azure_endpoint=AZURE_OPENAI_ENDPOINT,
        api_version="2023-05-15"
    )
else:
    pass

# %%
def get_embedding(text):
    response = openai_client.embeddings.create(
        model= AZURE_OPENAI_EMBEDDING_DEPLOYED_MODEL_NAME,
        input=text
    )

    return response.data[0].embedding

# %%
openai_client = AzureOpenAI(
        api_key=AZURE_OPENAI_API_KEY,
        azure_endpoint=AZURE_OPENAI_ENDPOINT,
        api_version="2023-05-15"
    )

def get_embedding(text):
    response = openai_client.embeddings.create(
        model=AZURE_OPENAI_EMBEDDING_DEPLOYED_MODEL_NAME,
        input=text
    )
    return response.data[0].embedding

results = {}
for scenario in scenarios:
    results[scenario['name']] = []
    index_name = f"{INDEX_PREFIX}-{scenario['name']}"
    search_client = SearchClient(AZURE_AI_SEARCH_BASIC_ENDPOINT, index_name, credential=AzureKeyCredential(AZURE_AI_SEARCH_BASIC_API_KEY))
    search_query = "first dinosaur in the fossil record"
    search_vector = get_embedding(search_query)
    r = search_client.search(
            top=5, 
            vector_queries=[
                    VectorizedQuery(vector=search_vector, k_nearest_neighbors=50, fields="embedding")])
    for doc in r:
        results[scenario['name']].append(doc["title"])

rows = []
headers = [scenario['name'] for scenario in scenarios]
for i in range(5):
    rows.append([results[scenario['name']][i] for scenario in scenarios])
tabulate(rows, headers=headers, tablefmt="html")
# Out:
# '<table>\n<thead>\n<tr><th>baseline        </th><th>baseline-s      </th><th>scalar-full     </th><th>scalar-truncated-1024  </th><th>scalar-truncated-1024-discard  </th><th>binary-full     </th><th>binary-truncated-1024  </th><th>binary-truncated-1024-discard  </th></tr>\n</thead>\n<tbody>\n<tr><td>Stephanosaurus  </td><td>Stephanosaurus  </td><td>Stephanosaurus  </td><td>Stephanosaurus         </td><td>Lessemsaurus                   </td><td>Stephanosaurus  </td><td>Stephanosaurus         </td><td>Atlascopcosaurus               </td></tr>\n<tr><td>Euskelosaurus   </td><td>Euskelosaurus   </td><td>Euskelosaurus   </td><td>Euskelosaurus          </td><td>Fabrosaurus                    </td><td>Euskelosaurus   </td><td>Euskelosaurus          </td><td>Stephanosaurus                 </td></tr>\n<tr><td>Stokesosaurus   </td><td>Stokesosaurus   </td><td>Stokesosaurus   </td><td>Stokesosaurus          </td><td>Tetraceratops                  </td><td>Stokesosaurus   </td><td>Stokesosaurus          </td><td>Fabrosaurus                    </td></tr>\n<tr><td>Dysalotosaurus  </td><td>Dysalotosaurus  </td><td>Dysalotosaurus  </td><td>Dysalotosaurus         </td><td>Therizinosauridae              </td><td>Dysalotosaurus  </td><td>Dysalotosaurus         </td><td>Euskelosaurus                  </td></tr>\n<tr><td>Brachypodosaurus</td><td>Brachypodosaurus</td><td>Brachypodosaurus</td><td>Brachypodosaurus       </td><td>Ouranosaurus                   </td><td>Brachypodosaurus</td><td>Brachypodosaurus       </td><td>Lessemsaurus                   </td></tr>\n</tbody>\n</table>'
